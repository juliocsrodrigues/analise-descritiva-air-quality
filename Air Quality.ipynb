# %% [markdown]
# <h2 style="text-align: center; font-weight: bold;font-size: 20px">Sobre a base de dados</h2>
#
# <p>O conjunto de dados contém 9358 instâncias de respostas médias horárias de um conjunto de 5 sensores químicos de óxido metálico embutidos em um Dispositivo Multissensor Químico de Qualidade do Ar. O dispositivo foi localizado em campo, em uma área significativamente poluída, no nível da estrada, dentro de uma cidade italiana. Os dados foram registrados de março de 2004 a fevereiro de 2005 (um ano) representando os registros mais longos disponíveis gratuitamente das respostas dos dispositivos de sensores químicos de qualidade do ar implantados em campo.</p>
#
# <p>As concentrações médias horárias do Ground Truth para CO, Hidrocarbonetos Não Mânicos, Benzeno, Óxidos de Nitrogênio Total (NOx) e Dióxido de Nitrogênio (NO2) foram fornecidas por um analisador certificado de referência co-localizado. Evidências de sensibilidades cruzadas, bem como derivas de conceitos e sensores estão presentes, conforme descrito em De Vito et al., Sens. And Act. B, Vol. 129,2,2008 (citação necessária), eventualmente afetando as capacidades de estimativa de concentração dos sensores.</p>
#
# <p>Os valores ausentes são marcados com o valor -200. Este conjunto de dados pode ser usado exclusivamente para fins de pesquisa. As finalidades comerciais estão totalmente excluídas.</p>
#
# <table>
#     <caption style="text-align: center; font-weight: bold;font-size: 20px">Dicionário de dados</caption>
#     <thead>
#         <tr>
#             <th>Variável</th>
#             <th>Tipo</th>
#             <th>Domínio</th>
#             <th>Descrição</th>
#             <th>Unidades</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Date</td>
#             <td>Data</td>
#             <td></td>
#             <td></td>
#             <td></td>
#         </tr>
#         <tr>
#             <td>Time</td>
#             <td>Categórica</td>
#             <td></td>
#             <td></td>
#             <td></td>
#         </tr>
#         <tr>
#             <td>CO(GT)</td>
#             <td>Inteira</td>
#             <td>Monóxido de carbono</td>
#             <td>Concentração média horária real de CO em mg/m^3 (analisador de referência)</td>
#             <td>mg/m^3</td>
#         </tr>
#         <tr>
#             <td>PT08.S1(CO)</td>
#             <td>Categórica</td>
#             <td></td>
#             <td>Resposta média horária do sensor (nominalmente CO direcionado)</td>
#             <td></td>
#         </tr>
#         <tr>
#             <td>NMHC(GT)</td>
#             <td>Inteira</td>
#             <td>Hidrocarbonetos não metano</td>
#             <td>Concentração média horária real de hidrocarbonetos não metânicos em microg/m^3 (analisador de referência)</td>
#             <td>microg/m^3</td>
#         </tr>
#         <tr>
#             <td>C6H6(GT)</td>
#             <td>Contínua</td>
#             <td>Benzeno</td>
#             <td>Concentração média horária real de benzeno em microg/m^3 (analisador de referência)</td>
#             <td>microg/m^3</td>
#         </tr>
#         <tr>
#             <td>PT08.S2(NMHC)</td>
#             <td>Categórica</td>
#             <td></td>
#             <td>Resposta média horária do sensor (nominalmente direcionada a NMHC)</td>
#             <td></td>
#         </tr>
#         <tr>
#             <td>NOx(GT)</td>
#             <td>Inteira</td>
#             <td>Óxidos de nitrogênio (NOx)</td>
#             <td>Concentração média horária verdadeira de NOx em parte por bilhão(analisador de referência)</td>
#             <td>ppb</td>
#         </tr>
#         <tr>
#             <td>PT08.S3(NOx)</td>
#             <td>Categórica</td>
#             <td></td>
#             <td>Resposta média horária do sensor (nominalmente direcionada ao NOx)</td>
#             <td></td>
#         </tr>
#         <tr>
#             <td>NO2(GT)</td>
#             <td>Inteira</td>
#             <td>Dióxido de nitrogênio</td>
#             <td>Concentração média verdadeira de NO2 por hora em microg/m^3 (analisador de referência)</td>
#             <td>microg/m^3</td>
#         </tr>
#         <tr>
#             <td>PT08.S4(NO2)</td>
#             <td>Categórica</td>
#             <td></td>
#             <td>Resposta média horária do sensor (nominalmente direcionada para NO2)</td>
#             <td></td>
#         </tr>
#         <tr>
#             <td>PT08.S5(O3)</td>
#             <td>Categórica</td>
#             <td>Ozônio</td>
#             <td>Resposta média horária do sensor (nominalmente direcionada para O3)</td>
#             <td></td>
#         </tr>
#         <tr>
#             <td>T</td>
#             <td>Contínua</td>
#             <td></td>
#             <td>Temperatura</td>
#             <td>°C</td>
#         </tr>
#         <tr>
#             <td>RH</td>
#             <td>Contínua</td>
#             <td></td>
#             <td>Umidade relativa</td>
#             <td>%</td>
#         </tr>
#         <tr>
#             <td>AH</td>
#             <td>Contínua</td>
#             <td></td>
#             <td>Umidade Absoluta</td>
#             <td></td>
#         </tr>
#     </tbody>
# </table>
#
# <h2 style="text-align: center; font-weight: bold;font-size: 20px">Obejetivo da análise:</h2>
#
# <p>Como as concentrações médias horárias variam entre os diferentes poluentes (CO e NO2)?
#
# Há alguma correlação entre as concentrações de diferentes poluentes?</p>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import numpy as np
import os 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import statsmodels.api as sm
df = pd.read_excel('C://Users//guigu//OneDrive//Área de Trabalho//Air Quality//AirQualityUCI - Copia.xlsx')

# %%
df.info
# Out:
# <bound method DataFrame.info of            Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  \
# 0    2004-03-10  18:00:00     2.6      1360.00       150  11.881723
# 1    2004-03-10  19:00:00     2.0      1292.25       112   9.397165
# 2    2004-03-10  20:00:00     2.2      1402.00        88   8.997817
# 3    2004-03-10  21:00:00     2.2      1375.50        80   9.228796
# 4    2004-03-10  22:00:00     1.6      1272.25        51   6.518224
# ...         ...       ...     ...          ...       ...        ...
# 9352 2005-04-04  10:00:00     3.1      1314.25      -200  13.529605
# 9353 2005-04-04  11:00:00     2.4      1162.50      -200  11.355157
# 9354 2005-04-04  12:00:00     2.4      1142.00      -200  12.374538
# 9355 2005-04-04  13:00:00     2.1      1002.50      -200   9.547187
# 9356 2005-04-04  14:00:00     2.2      1070.75      -200  11.932060
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# ...

# %%
df.describe()
# Out:
#             CO(GT)  PT08.S1(CO)     NMHC(GT)     C6H6(GT)  PT08.S2(NMHC)  \
# count  9357.000000  9357.000000  9357.000000  9357.000000    9357.000000
# mean    -34.207524  1048.869652  -159.090093     1.865576     894.475963
# std      77.657170   329.817015   139.789093    41.380154     342.315902
# min    -200.000000  -200.000000  -200.000000  -200.000000    -200.000000
# 25%       0.600000   921.000000  -200.000000     4.004958     711.000000
# 50%       1.500000  1052.500000  -200.000000     7.886653     894.500000
# 75%       2.600000  1221.250000  -200.000000    13.636091    1104.750000
# max      11.900000  2039.750000  1189.000000    63.741476    2214.000000
#
#            NOx(GT)  PT08.S3(NOx)      NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# count  9357.000000   9357.000000  9357.000000   9357.000000  9357.000000
# mean    168.604200    794.872333    58.135898   1391.363266   974.951534
# std     257.424561    321.977031   126.931428    467.192382   456.922728
# ...

# %%
df.isnull().sum()
# Out:
# Date             0
# Time             0
# CO(GT)           0
# PT08.S1(CO)      0
# NMHC(GT)         0
# C6H6(GT)         0
# PT08.S2(NMHC)    0
# NOx(GT)          0
# PT08.S3(NOx)     0
# NO2(GT)          0
# PT08.S4(NO2)     0
# PT08.S5(O3)      0
# T                0
# RH               0
# AH               0
# dtype: int64

# %%
df2 = df.copy()

# %%
# Substituir -200 pelos valores médios em cada coluna
for col in columns_to_replace:
    col_mean = df2.loc[df2[col] != -200, col].mean()
    df2[col] = df2[col].replace(-200, col_mean)

# Recalcular a média após a substituição
new_means = df2[columns_to_replace].apply(lambda col: col.mean())

# %%
df2.describe()
# Out:
#             CO(GT)  PT08.S1(CO)     NMHC(GT)     C6H6(GT)  PT08.S2(NMHC)  \
# count  9357.000000  9357.000000  9357.000000  9357.000000    9357.000000
# mean      2.152750  1099.707856   218.811816    10.082993     939.029205
# std       1.316068   212.796116    63.870229     7.302474     261.557856
# min       0.100000   647.250000     7.000000     0.149048     383.250000
# 25%       1.200000   941.250000   218.811816     4.591495     742.500000
# 50%       2.152750  1074.500000   218.811816     8.593367     923.250000
# 75%       2.600000  1221.250000   218.811816    13.636091    1104.750000
# max      11.900000  2039.750000  1189.000000    63.741476    2214.000000
#
#            NOx(GT)  PT08.S3(NOx)      NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# count  9357.000000   9357.000000  9357.000000   9357.000000  9357.000000
# mean    246.881252    835.370973   113.075515   1456.143486  1022.780725
# std     193.419417    251.741784    43.911095    339.365351   390.609000
# ...

# %%
filter_columns = ['CO(GT)', 'NMHC(GT)','C6H6(GT)','NOx(GT)','NO2(GT)']
df3 = df2[filter_columns].copy()
df3.head()
# Out:
#    CO(GT)  NMHC(GT)   C6H6(GT)  NOx(GT)  NO2(GT)
# 0     2.6     150.0  11.881723    166.0    113.0
# 1     2.0     112.0   9.397165    103.0     92.0
# 2     2.2      88.0   8.997817    131.0    114.0
# 3     2.2      80.0   9.228796    172.0    122.0
# 4     1.6      51.0   6.518224    131.0    116.0

# %%
correlation = df3.corr()
plot = sns.heatmap(correlation, annot = True, fmt=".1f", linewidths=.50)
plt.figure (figsize= (12, 8))
plt.show()

# %%
df2['NOx(GT)'].plot(kind='hist', bins=10, edgecolor='black')
plt.xlabel('NOx(GT) óxidos de nitrogênio')
plt.ylabel('Unidade ppb')
plt.title('Disperção de óxidos de nitrogênio')
plt.show()

# %%
df2['NO2(GT)'].plot(kind='hist', bins=10, edgecolor='black')
plt.xlabel('NO2(GT) Dióxido de nitrogênio')
plt.ylabel('Unidade micro/m^3')
plt.title('Disperção de Dióxido de nitrogênio')
plt.show()

# %% [markdown]
# <p>Podemos perceber que tanto NOx(GT) como para NO2(GT), os histogramas apresentam assimetria à esquerda, ou seja, assimetria positiva, representando que temos muitas observação com valores inferiores a média.</p>

# %%
plt.scatter(df2['NOx(GT)'], df2['NO2(GT)'])
plt.title('Gráfico de Dispersão entre Poluente NOx(GT) óxidos de nitrogênio e NO2(GT) Dióxido de nitrogênio')
plt.xlabel('NOx(GT) óxidos de nitrogênio')
plt.ylabel('NO2(GT) Dióxido de nitrogênio')
# plt.xlim(0,1400)
# plt.ylim(0 1400)
plt.show()

# %% [markdown]
# <p>seguindo a analise do nosso grafico de dispersão, os pontos estão sempre muito proximos o que pode indicar que os dados </p>

# %%
X = df3['NOx(GT)'].values.reshape(-1,1)
y = df3['NO2(GT)'].values.reshape(-1,1)
reg = LinearRegression()
reg.fit(X, y)

print("O modelo linear é apresentado: Y = {:.5} + {:.5}X".format(reg.intercept_[0], reg.coef_[0][0]))
# Out:
# O modelo linear é apresentado: Y = 70.303 + 0.17325X

# %%
predictions = reg.predict(X)
plt.figure(figsize=(16, 8))
plt.scatter(
    df3['NOx(GT)'],
    df3['NO2(GT)'],
    c='black'
)
plt.plot(
    df3['NOx(GT)'],
    predictions,
    c='blue',
    linewidth=2
)
plt.xlabel("NOx(GT) óxidos de nitrogênio")
plt.ylabel("NO2(GT) Dióxido de nitrogênio")
plt.show()

# %%
X = df3['NOx(GT)']
y = df3['NO2(GT)']
X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                NO2(GT)   R-squared:                       0.582
# Model:                            OLS   Adj. R-squared:                  0.582
# Method:                 Least Squares   F-statistic:                 1.305e+04
# Date:                Tue, 21 Nov 2023   Prob (F-statistic):               0.00
# Time:                        17:15:01   Log-Likelihood:                -44581.
# No. Observations:                9357   AIC:                         8.917e+04
# Df Residuals:                    9355   BIC:                         8.918e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         70.3032      0.476    147.783      0.000      69.371      71.236
# ...

# %% [markdown]
# <p>Realizamos a importação do arquivo excel</p>

# %%
#df['Date'] = pd.to_numeric(df['Date'])
df['Date'] = pd.to_datetime(df['Date'])

# # Criar três novas colunas numéricas com o ano, mês e dia
df['Ano'] = df['Date'].dt.year
df['Mes'] = df['Date'].dt.month
df['Dia'] = df['Date'].dt.day

# # Converter as novas colunas em valores inteiros
df['Ano'] = df['Ano'].astype(int)
df['Mes'] = df['Mes'].astype(int)
df['Dia'] = df['Dia'].astype(int)
df.head(10)
# Out:
#         Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  \
# 0 2004-03-10  18:00:00     2.6      1360.00       150  11.881723
# 1 2004-03-10  19:00:00     2.0      1292.25       112   9.397165
# 2 2004-03-10  20:00:00     2.2      1402.00        88   8.997817
# 3 2004-03-10  21:00:00     2.2      1375.50        80   9.228796
# 4 2004-03-10  22:00:00     1.6      1272.25        51   6.518224
# 5 2004-03-10  23:00:00     1.2      1197.00        38   4.741012
# 6 2004-03-11  00:00:00     1.2      1185.00        31   3.624399
# 7 2004-03-11  01:00:00     1.0      1136.25        31   3.326677
# 8 2004-03-11  02:00:00     0.9      1094.00        24   2.339416
# 9 2004-03-11  03:00:00     0.6      1009.75        19   1.696658
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0        1045.50    166.0       1056.25    113.0       1692.00      1267.50
# 1         954.75    103.0       1173.75     92.0       1558.75       972.25
# ...

# %% [markdown]
# <p>Para uma possivel analise foi separado a coluna (Date) para novas três colunas
# (Ano, mês e dia) e sendo mostrado para verificarmos os dados</p>

# %%
df2 = df.copy()

# %% [markdown]
# <p>Foi copiado o dataframe para um novo para podermos manipular os dados sem afetar os dados originais</p>

# %%
df2.describe()
# Out:
#             CO(GT)  PT08.S1(CO)     NMHC(GT)     C6H6(GT)  PT08.S2(NMHC)  \
# count  9357.000000  9357.000000  9357.000000  9357.000000    9357.000000
# mean    -34.207524  1048.869652  -159.090093     1.865576     894.475963
# std      77.657170   329.817015   139.789093    41.380154     342.315902
# min    -200.000000  -200.000000  -200.000000  -200.000000    -200.000000
# 25%       0.600000   921.000000  -200.000000     4.004958     711.000000
# 50%       1.500000  1052.500000  -200.000000     7.886653     894.500000
# 75%       2.600000  1221.250000  -200.000000    13.636091    1104.750000
# max      11.900000  2039.750000  1189.000000    63.741476    2214.000000
#
#            NOx(GT)  PT08.S3(NOx)      NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# count  9357.000000   9357.000000  9357.000000   9357.000000  9357.000000
# mean    168.604200    794.872333    58.135898   1391.363266   974.951534
# std     257.424561    321.977031   126.931428    467.192382   456.922728
# ...

# %% [markdown]
# <p>Ultiliza o metodo describe para entender ter uma melhor visão dos dados do dataframe copiado</p>

# %%
df2.isnull().sum()
# Out:
# Date             0
# Time             0
# CO(GT)           0
# PT08.S1(CO)      0
# NMHC(GT)         0
# C6H6(GT)         0
# PT08.S2(NMHC)    0
# NOx(GT)          0
# PT08.S3(NOx)     0
# NO2(GT)          0
# PT08.S4(NO2)     0
# PT08.S5(O3)      0
# T                0
# RH               0
# AH               0
# Ano              0
# Mes              0
# Dia              0
# dtype: int64

# %% [markdown]
# <p>A função isnull nos traz os dados nulos no data frame porém na nossa tabela esses dados são tratados como -200 e não como nulos , foi feito para verificamos se todos os dados nulos realmente estão como -200</p>

# %% [markdown]
# ## Calculo de concentração - NO2(GT)

# %%
MED_NO2 = 0
df2['NO2(GT)'] = pd.to_numeric(df2['NO2(GT)'], errors='coerce')

# %% [markdown]
# <p>Convertemos a coluna 'NO2(GT)' para tipo numérico, tratando os valores -200.0 como NaN E incializando a variavel para 0</p>

# %%
df_Med_Parcial_NO2 = df2.loc[df2['NO2(GT)'] != -200.0, ['NO2(GT)']].copy()

# %% [markdown]
# <p>Criamos um novo DataFrame chamado df_Med_Parcial_NO2(GT) copiando a coluna 'NO2(GT)' sem os valores -200 para conseguirmos realizar a media</p>

# %%
df_Med_Final_NO2 = df2[['NO2(GT)']].copy()
df_Med_Final_NO2.loc[df_Med_Final_NO2['NO2(GT)']== -200.0] = MED_NO2
MED_NO2 = df_Med_Final_NO2.mean()

# %% [markdown]
# <p>Criando um novo dataframe para receber o valor da media nos valores nulos e recalcular a media final com todos os valores</p>

# %%
MED_NO2 = df_Med_Parcial_NO2['NO2(GT)'].mean()
MIN_NO2 = df_Med_Parcial_NO2['NO2(GT)'].min()
MAX_NO2 = df_Med_Parcial_NO2['NO2(GT)'].max()

# %% [markdown]
# <p>Calculamos a média do dataframe df_Med_Parcial_NO2</p>

# %%
df_Med_Final_NO2 = df2[['NO2(GT)']].copy()
df_Med_Final_NO2.loc[df_Med_Final_NO2['NO2(GT)']== -200.0] = MED_NO2
MED_NO2 = df_Med_Final_NO2.mean()
print(MED_NO2)
# Out:
# NO2(GT)    113.075515
# dtype: float64

# %% [markdown]
# <p>Criando um dataframe para calcular a media final e atribuir na variavel</p>

# %% [markdown]
# | Qualidade | Índice | Níveis de Cautela sobre a Saúde | NO2 (µg/m3) |
# |-----------|--------|--------------------------------|-------------|
# | Boa       | 0-50   | 0-80                           | 0-4,5       |
# | Regular   | 51-100 | 81-240                         | 51-150      |
# | Inadequada| 101-199| Insalubre para grupos sensíveis | 241-375     |
# | Má        | 200-299| Muito insalubre                 | 376-625     |
# | Péssima   | 300-399| Perigoso                        | 626-875     |
# | Crítica   | Acima de 400 | Muito perigoso           | > 876       |

# %% [markdown]
# <p>O cálculo indica que a concentração existente de NO2 no ar torna a qualidade do ar como: **Regular**, por estar entre os níveis de 51 a 150 (µg/m3)</p>

# %% [markdown]
# ## Calculo de concentração - CO(GT)

# %%
MED_CO = 0
df2['CO(GT)'] = pd.to_numeric(df2['CO(GT)'], errors='coerce')

# %% [markdown]
# <p>Convertemos a coluna 'NO2(GT)' para tipo numérico, tratando os valores -200.0 como NaN E incializando a variavel para 0/<p>

# %%
df_Med_Parcial_CO = df2.loc[df2['CO(GT)'] != -200.0, ['CO(GT)']].copy()

# %% [markdown]
# <p>Criamos um novo DataFrame chamado df_Med_Parcial_CO copiando a coluna 'CO(GT)' sem os valores -200 para conseguirmos realizar a media</p>

# %%
df_Med_Final_CO = df2[['CO(GT)']].copy()
df_Med_Final_CO.loc[df_Med_Final_CO['CO(GT)']== -200.0] = MED_CO
MED_CO = df_Med_Final_CO.mean()

# %% [markdown]
# <p>Criando um novo dataframe para receber o valor da media nos valores nulos e recalcular a media final com todos os valores</p>

# %%
MED_CO = df_Med_Parcial_CO['CO(GT)'].mean()
MIN_CO = df_Med_Parcial_CO['CO(GT)'].min()
MAX_CO = df_Med_Parcial_CO['CO(GT)'].max()

# %% [markdown]
# <p>Calculamos a média, maximo e minimo do dataframe df_Med_Parcial_CO</p>

# %%
df_Med_Final_CO = df2[['CO(GT)']].copy()
df_Med_Final_CO.loc[df_Med_Final_CO['CO(GT)']== -200.0] = MED_CO
MED_CO = df_Med_Final_CO.mean()
print(MED_CO)
# Out:
# CO(GT)    2.15275
# dtype: float64

# %% [markdown]
# <p>Relizado o calculo de conversão para ppm(partes por milhão) onde os valores(massa_molar_co e fator_conversao_comum)</p>

# %%
concentracao_co_mg_m3 = MED_CO
massa_molar_co = 28.01
fator_conversao_comum = 24.45
concentracao_co_ppm = (concentracao_co_mg_m3 / massa_molar_co) * fator_conversao_comum
print(concentracao_co_ppm)
# Out:
# CO(GT)    1.879141
# dtype: float64

# %% [markdown]
# <p>Relizado o calculo de conversão para ppm(partes por milhão) onde os valores(massa_molar_co e fator_conversao_comum)</p>

# %% [markdown]
# <p>O calculo indica que a concentração existente de CO no ar torna a qualidade do ar como: Boa, por estar entre os niveis de 0 a 4,5 ppm</p>

# %% [markdown]
# | Qualidade | Índice | Níveis de Cautela sobre a Saúde | CO (ppm) |
# |-----------|--------|--------------------------------|----------|
# | Boa       | 0-50   | 0-80                           | 0-4,5    |
# | Regular   | 51-100 | 81-160                         | 4,6-9,0  |
# | Inadequada| 101-199| Insalubre para grupos sensíveis | 9,1-12,4*|
# | Má        | 200-299| Muito insalubre                 | 15,1-30  |
# | Péssima   | 300-399| Perigoso                        | 30,1-40  |
# | Crítica   | Acima de 400 | Muito perigoso               | > 40     |

# %% [markdown]
# ## Conclusão

# %% [markdown]
# <p>Nesta analise realizada na base de dados Air Quality testamos duas hipoteses:(Como as concentrações médias anuais variam entre os diferentes poluentes (CO e NO2)? e se há alguma correlação entre as concentrações de diferentes poluentes?).</p>
# <p>Na primeira Hipotese podemos comparar a concentração de dois elementos o (Monóxido de carbono e Dióxido de nitrogênio) com base no calculo do Indice de Qualidade do Ar(IQAR), em ambos os elementos foi usado os dados de um ano, e podemos observar pelos valores informados é que o:</p>
#     <p><strong>CO</strong> - A classificação de (Boa) mostra que o valor de concentração está compreendido entre 0 e 50 mostrando que a qualidade do ar é satisfatória e
# apresenta pouco ou nenhum risco para a saúde da população.</p>
#     <p><strong>CO</strong> - A classificação de (Regular) mostraque o valor de concentração esta entre 51 e 100. Nesta faixa, a qualidade do ar é aceitável, porém as concentrações existentes no ar podem causar uma preocupação moderada à saúde
# para um número muito pequenos de indivíduos. Pessoas com extrema sensibilidade ao Dióxido de nitrogênio podem experimentar problemas respiratórios.</p>
# <p>Em relação à segunda hipótese, com um R-squared de 0.582, observamos que aproximadamente 58.2% da nossa análise é explicada pelas variáveis no modelo.</p>

# %% [markdown]
# ## Fontes
# https://jeap.rio.rj.gov.br/je-metinfosmac/institucional/docs/entenda_iqa.pdf
# https://www.legisweb.com.br/legislacao/?id=369516
# https://www.pranaair.com/pt-pt/blog/what-is-air-quality-index-aqi-and-its-calculation/#:~:text=Para%20calcular%20o%20AQI%2C%20os,efeitos%20na%20sa%C3%BAde%20de%20acordo.
# https://www.in.gov.br/web/guest/materia/-/asset_publisher/Kujrw0TZC2Mb/content/id/51058895/do1-2018-11-21-resolucao-n-491-de-19-de-novembro-de-2018-51058603
